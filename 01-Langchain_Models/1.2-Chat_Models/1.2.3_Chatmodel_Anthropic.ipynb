# %% [markdown]
# ## Chat model from Anthropic
# **Claude is a family of advanced AI language models created by Anthropic, designed to be safe, accurate, and capable of handling complex reasoning, coding, and multimodal tasks. The latest generation, Claude 4.5, includes specialized models like Opus, Sonnet, and Haiku, each optimized for different use cases.**
#
# ---
#
# ### 🧠 What Claude Is
# - **Developer:** Anthropic, an AI safety and research company.
# - **Type:** Large Language Model (LLM), similar to GPT but with a strong emphasis on safety and reliability.
# - **Capabilities:**
#   - Text and image input, text output.
#   - Multilingual support.
#   - Vision capabilities (can analyze images).
#   - Advanced reasoning, coding, and agent workflows.
#
# ---
#
# ### 📊 Claude Model Variants (Claude 4.5 Series)
#
# | Model        | Key Strengths | Best Use Cases |
# |--------------|---------------|----------------|
# | **Claude Opus 4.5** | Maximum intelligence, deep reasoning, best coding performance | Complex coding tasks, long-running agent workflows |
# | **Claude Sonnet 4.5** | Balanced speed, intelligence, and cost | General-purpose tasks, explanations, coding, productivity |
# | **Claude Haiku 4.5** | Fastest model, lightweight | Quick responses, real-time chat, simple queries |
#
#
#
# ---
#
# ### 🔑 Why Claude Stands Out
# - **Safety-first design:** Anthropic emphasizes alignment and reduced harmful outputs.
# - **Integration options:** Available via **Anthropic API**, **AWS Bedrock**, and **Google Vertex AI**.
# - **Artifacts feature:** Lets users generate and edit documents, code, or graphics alongside chat.
# - **Pricing tiers:** Free access for basic use, with paid plans for professional and enterprise needs.
#
# ---
#
# ### ⚖️ Claude vs Other Models
# - **Compared to GPT (OpenAI):** Claude focuses more on safety and interpretability, while GPT emphasizes broad creativity and scale.
# - **Compared to Gemini (Google):** Claude is tuned for agentic workflows and coding, whereas Gemini emphasizes multimodal creativity.
# - **Compared to Hugging Face models:** Claude is proprietary and optimized for enterprise-grade reasoning, while Hugging Face offers open-source flexibility.
#
# ---
#
# ### 🚀 Practical Takeaway
# If you’re working on **LangChain integrations** (like in your earlier notes), Claude can be used via the `langchain-anthropic` package. It’s especially useful for **agent workflows, coding-heavy tasks, and safe reasoning applications**. For balanced everyday use, **Claude Sonnet 4.5** is the recommended starting point.
#
#
# <br/>
#
# It is also a paid model. So, first you should purchase some tokens and then proceed.
#
# url = https://platform.claude.com/docs/en/intro

# %%
from langchain_anthropic import ChatAnthropic
